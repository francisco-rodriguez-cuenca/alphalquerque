# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
elo_df = (
    pd.read_csv("ELO.csv", sep = ";")
    .rename(columns = {"Unnamed: 0": "filepath"})
    .assign(
        configuration = lambda a: a.filepath.str.split("/").str[-2],
        iteration = lambda a: a.filepath.str.split("/").str[-1].str.split("_").str[-1].str.split(".").str[0].astype("int"),
        ELO = lambda a: a.ELO + abs(a.ELO.min())
    )
    .sort_values(["configuration", "iteration"])
)
elo_df
# Out:
#                                              filepath         ELO  \
# 0         best_models/100_nonsymetric/checkpoint_1.h5    0.000000
# 7         best_models/100_nonsymetric/checkpoint_2.h5  113.722497
# 13        best_models/100_nonsymetric/checkpoint_3.h5  108.652863
# 17        best_models/100_nonsymetric/checkpoint_4.h5  118.178125
# 19        best_models/100_nonsymetric/checkpoint_5.h5  224.312110
# 20        best_models/100_nonsymetric/checkpoint_8.h5  304.602120
# 21        best_models/100_nonsymetric/checkpoint_9.h5  236.174710
# 1        best_models/100_nonsymetric/checkpoint_10.h5  245.354526
# 2        best_models/100_nonsymetric/checkpoint_11.h5  213.124819
# 3        best_models/100_nonsymetric/checkpoint_12.h5  254.673475
# 4        best_models/100_nonsymetric/checkpoint_13.h5  229.742007
# 5        best_models/100_nonsymetric/checkpoint_14.h5  248.454652
# 6        best_models/100_nonsymetric/checkpoint_17.h5  290.060930
# 8        best_models/100_nonsymetric/checkpoint_20.h5  230.701532
# 9        best_models/100_nonsymetric/checkpoint_25.h5  286.529489
# 10       best_models/100_nonsymetric/checkpoint_27.h5  243.012447
# 11       best_models/100_nonsymetric/checkpoint_28.h5  284.579696
# 12       best_models/100_nonsymetric/checkpoint_29.h5  269.663233
# 14       best_models/100_nonsymetric/checkpoint_30.h5  301.058945
# 15       best_models/100_nonsymetric/checkpoint_35.h5  284.723961
# 16       best_models/100_nonsymetric/checkpoint_38.h5  290.896317
# 18       best_models/100_nonsymetric/checkpoint_41.h5  292.237803
# 22  best_models/200_nonsymetric_10max/checkpoint_1.h5  132.285221
# 29  best_models/200_nonsymetric_10max/checkpoint_2.h5  161.299927
# 35  best_models/200_nonsymetric_10max/checkpoint_4.h5  249.881059
# 36  best_models/200_nonsymetric_10max/checkpoint_5.h5  241.723529
# 37  best_models/200_nonsymetric_10max/checkpoint_6.h5  204.144423
# 38  best_models/200_nonsymetric_10max/checkpoint_7.h5  274.719365
# 44  best_models/200_nonsymetric_10max/checkpoint_9.h5  280.743106
# 23  best_models/200_nonsymetric_10max/checkpoint_1...  251.593199
# 24  best_models/200_nonsymetric_10max/checkpoint_1...  318.966947
# 25  best_models/200_nonsymetric_10max/checkpoint_1...  325.407072
# 26  best_models/200_nonsymetric_10max/checkpoint_1...  324.614280
# 27  best_models/200_nonsymetric_10max/checkpoint_1...  363.583778
# 28  best_models/200_nonsymetric_10max/checkpoint_1...  399.551386
# 30  best_models/200_nonsymetric_10max/checkpoint_2...  347.133471
# 31  best_models/200_nonsymetric_10max/checkpoint_2...  308.998507
# 32  best_models/200_nonsymetric_10max/checkpoint_2...  407.068799
# 33  best_models/200_nonsymetric_10max/checkpoint_2...  317.915157
# 34  best_models/200_nonsymetric_10max/checkpoint_3...  390.985454
# 39  best_models/200_nonsymetric_10max/checkpoint_7...  418.176731
# 40  best_models/200_nonsymetric_10max/checkpoint_7...  445.331734
# 41  best_models/200_nonsymetric_10max/checkpoint_7...  436.028516
# 42  best_models/200_nonsymetric_10max/checkpoint_8...  340.965946
# 43  best_models/200_nonsymetric_10max/checkpoint_8...  361.532392
# 45  best_models/200_nonsymetric_10max/checkpoint_9...  389.488110
# 46  best_models/200_nonsymetric_10max/checkpoint_9...  370.926486
# 47  best_models/200_nonsymetric_10max_100MCTS/chec...  262.578357
# 50  best_models/200_nonsymetric_10max_100MCTS/chec...  320.634829
# 51  best_models/200_nonsymetric_10max_100MCTS/chec...  331.374067
# 52  best_models/200_nonsymetric_10max_100MCTS/chec...  490.692538
# 53  best_models/200_nonsymetric_10max_100MCTS/chec...  423.308223
# 48  best_models/200_nonsymetric_10max_100MCTS/chec...  517.481793
# 49  best_models/200_nonsymetric_10max_100MCTS/chec...  502.023072
#
#                     configuration  iteration
# 0                 100_nonsymetric          1
# 7                 100_nonsymetric          2
# 13                100_nonsymetric          3
# 17                100_nonsymetric          4
# 19                100_nonsymetric          5
# 20                100_nonsymetric          8
# 21                100_nonsymetric          9
# 1                 100_nonsymetric         10
# 2                 100_nonsymetric         11
# 3                 100_nonsymetric         12
# 4                 100_nonsymetric         13
# 5                 100_nonsymetric         14
# 6                 100_nonsymetric         17
# 8                 100_nonsymetric         20
# 9                 100_nonsymetric         25
# 10                100_nonsymetric         27
# 11                100_nonsymetric         28
# 12                100_nonsymetric         29
# 14                100_nonsymetric         30
# 15                100_nonsymetric         35
# 16                100_nonsymetric         38
# 18                100_nonsymetric         41
# 22          200_nonsymetric_10max          1
# 29          200_nonsymetric_10max          2
# 35          200_nonsymetric_10max          4
# 36          200_nonsymetric_10max          5
# 37          200_nonsymetric_10max          6
# 38          200_nonsymetric_10max          7
# 44          200_nonsymetric_10max          9
# 23          200_nonsymetric_10max         10
# 24          200_nonsymetric_10max         12
# 25          200_nonsymetric_10max         14
# 26          200_nonsymetric_10max         15
# 27          200_nonsymetric_10max         17
# 28          200_nonsymetric_10max         18
# 30          200_nonsymetric_10max         21
# 31          200_nonsymetric_10max         22
# 32          200_nonsymetric_10max         23
# 33          200_nonsymetric_10max         24
# 34          200_nonsymetric_10max         30
# 39          200_nonsymetric_10max         74
# 40          200_nonsymetric_10max         77
# 41          200_nonsymetric_10max         79
# 42          200_nonsymetric_10max         81
# 43          200_nonsymetric_10max         82
# 45          200_nonsymetric_10max         93
# 46          200_nonsymetric_10max         94
# 47  200_nonsymetric_10max_100MCTS          1
# 50  200_nonsymetric_10max_100MCTS          2
# 51  200_nonsymetric_10max_100MCTS          3
# 52  200_nonsymetric_10max_100MCTS          7
# 53  200_nonsymetric_10max_100MCTS          8
# 48  200_nonsymetric_10max_100MCTS         13
# 49  200_nonsymetric_10max_100MCTS         15

# %%
(
    elo_df
    .set_index("iteration")
    .assign(
        configuration = lambda a: a.configuration.replace({
            "100_nonsymetric": "ligero",
            "200_nonsymetric_10max": "medio",
            "200_nonsymetric_10max_100MCTS": "pesado"
        })
    )
    .groupby("configuration")
    .ELO
    .plot(legend=True, use_index=True, figsize = (20,10))
)
plt.xlabel("Iteración")
plt.ylabel("ELO")
# Out:
# Text(0, 0.5, 'ELO')

# %%
(
    elo_df
    .assign(
        training = lambda a: a.configuration.replace({
            "100_nonsymetric": "ligero",
            "200_nonsymetric_10max": "medio",
            "200_nonsymetric_10max_100MCTS": "pesado"
        })
    )
    [["training", "iteration", "ELO"]]
    .sort_values(["training", "iteration"])
)
# Out:
#    training  iteration         ELO
# 0    ligero          1    0.000000
# 7    ligero          2  113.722497
# 13   ligero          3  108.652863
# 17   ligero          4  118.178125
# 19   ligero          5  224.312110
# 20   ligero          8  304.602120
# 21   ligero          9  236.174710
# 1    ligero         10  245.354526
# 2    ligero         11  213.124819
# 3    ligero         12  254.673475
# 4    ligero         13  229.742007
# 5    ligero         14  248.454652
# 6    ligero         17  290.060930
# 8    ligero         20  230.701532
# 9    ligero         25  286.529489
# 10   ligero         27  243.012447
# 11   ligero         28  284.579696
# 12   ligero         29  269.663233
# 14   ligero         30  301.058945
# 15   ligero         35  284.723961
# 16   ligero         38  290.896317
# 18   ligero         41  292.237803
# 22    medio          1  132.285221
# 29    medio          2  161.299927
# 35    medio          4  249.881059
# 36    medio          5  241.723529
# 37    medio          6  204.144423
# 38    medio          7  274.719365
# 44    medio          9  280.743106
# 23    medio         10  251.593199
# 24    medio         12  318.966947
# 25    medio         14  325.407072
# 26    medio         15  324.614280
# 27    medio         17  363.583778
# 28    medio         18  399.551386
# 30    medio         21  347.133471
# 31    medio         22  308.998507
# 32    medio         23  407.068799
# 33    medio         24  317.915157
# 34    medio         30  390.985454
# 39    medio         74  418.176731
# 40    medio         77  445.331734
# 41    medio         79  436.028516
# 42    medio         81  340.965946
# 43    medio         82  361.532392
# 45    medio         93  389.488110
# 46    medio         94  370.926486
# 47   pesado          1  262.578357
# 50   pesado          2  320.634829
# 51   pesado          3  331.374067
# 52   pesado          7  490.692538
# 53   pesado          8  423.308223
# 48   pesado         13  517.481793
# 49   pesado         15  502.023072

# %% [markdown]
# ## Análisis Win/lose/draw

# %% [markdown]
# ### Ligero

# %%
light_df = (
    pd.read_csv("best_models/100_nonsymetric/100_nonsymetric_summary.txt", sep = ";")
    .rename(columns = {
        "win":"partidas ganadas",
        "lose": "partidas perdidas",
        "draw": "partidas empatadas"
    })
)
light_df.index = light_df.index + 1
light_df
# Out:
#      partidas ganadas  partidas perdidas  partidas empatadas
# 1                  29                  9                   2
# 2                  29                  6                   5
# 3                  20                 10                  10
# 4                  16                 13                  11
# 5                  15                 10                  15
# ..                ...                ...                 ...
# 96                  0                  0                  40
# 97                  0                  3                  37
# 98                  0                  0                  40
# 99                  0                  3                  37
# 100                 0                  0                  40
#
# [100 rows x 3 columns]

# %%
(
    light_df
    .plot(legend=True, use_index=True, figsize = (20,10), title = "Entrenamiento ligero", kind = "area")
)
plt.xlabel("Iteración")
plt.ylabel("Cantidad")
# Out:
# Text(0, 0.5, 'Cantidad')

# %% [markdown]
# ### Medio

# %%
medium_df = (
    pd.read_csv("best_models/200_nonsymetric_10max/200_nonsymetric_10max_summary.txt", sep = ";")
    .rename(columns = {
        "win":"partidas ganadas",
        "lose": "partidas perdidas",
        "draw": "partidas empatadas"
    })
)
medium_df.index = medium_df.index + 1
medium_df
# Out:
#      partidas ganadas  partidas perdidas  partidas empatadas
# 1                  32                  1                   7
# 2                  25                 10                   5
# 3                  17                 15                   8
# 4                  28                  8                   4
# 5                  17                 12                  11
# ..                ...                ...                 ...
# 96                  0                  0                  40
# 97                  0                  1                  39
# 98                  2                  8                  30
# 99                  0                  0                  40
# 100                 0                  0                  40
#
# [100 rows x 3 columns]

# %%
(
    medium_df
    .plot(legend=True, use_index=True, figsize = (20,10), title = "Entrenamiento medio", kind = "area")
)
plt.xlabel("Iteración")
plt.ylabel("Cantidad")
# Out:
# Text(0, 0.5, 'Cantidad')

# %% [markdown]
# ### Pesado

# %%
heavy_df = (
    pd.read_csv("best_models/200_nonsymetric_10max_100MCTS/200_nonsymetric_10max_100MCTS_summary.txt", sep = ";")
    .rename(columns = {
        "win":"partidas ganadas",
        "lose": "partidas perdidas",
        "draw": "partidas empatadas"
    })
)
heavy_df.index = heavy_df.index + 1
heavy_df
# Out:
#     partidas ganadas  partidas perdidas  partidas empatadas
# 1                 19                  0                   1
# 2                  7                  3                  10
# 3                 11                  0                   9
# 4                  3                  9                   8
# 5                  4                  5                  11
# 6                  1                  2                  17
# 7                  2                  1                  17
# 8                  8                  4                   8
# 9                  0                  2                  18
# 10                 2                  3                  15
# 11                 0                  2                  18
# 12                 1                  3                  16
# 13                 1                  0                  19
# 14                 1                  2                  17
# 15                 1                  0                  19

# %%
(
    heavy_df
    .plot(legend=True, use_index=True, figsize = (20,10), title = "Entrenamiento pesado", kind = "area")
)
plt.xlabel("Iteración")
plt.ylabel("Cantidad")
plt.yticks(range(0,20,5))
# Out:
# ([<matplotlib.axis.YTick at 0x7f6c69eaef10>,
#   <matplotlib.axis.YTick at 0x7f6c69eae510>,
#   <matplotlib.axis.YTick at 0x7f6c69eaad10>,
#   <matplotlib.axis.YTick at 0x7f6c69e84210>],
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %% [markdown]
# ### Todas juntas

# %%
fig, axs = plt.subplots(3, figsize = (20,20))

(
    light_df
    .plot(legend=True, use_index=True, title = "Entrenamiento ligero", kind = "area", ax = axs[0])
)
axs[0].legend(loc='upper right')
axs[0].set(xlabel="Iteración", ylabel="Cantidad")
(
    medium_df
    .plot(legend=True, use_index=True, title = "Entrenamiento medio", kind = "area", ax = axs[1])
)
axs[1].legend(loc='upper right')
axs[1].set(xlabel="Iteración", ylabel="Cantidad")
(
    heavy_df
    .plot(legend=True, use_index=True, title = "Entrenamiento pesado", kind = "area", ax = axs[2])
)
plt.yticks(range(0,20,5))
axs[2].legend(loc='upper right')
axs[2].set(xlabel="Iteración", ylabel="Cantidad")
# Out:
# [Text(0.5, 0, 'Iteración'), Text(0, 0.5, 'Cantidad')]
